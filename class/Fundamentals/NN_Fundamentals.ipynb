# %% [markdown]
# It is highly recommended to use a powerful **GPU**, you can use it for free uploading this notebook to [Google Colab](https://colab.research.google.com/notebooks/intro.ipynb).
# <table align="center">
#  <td align="center"><a target="_blank" href="https://colab.research.google.com/github/ezponda/intro_deep_learning/blob/main/class/Fundamentals/NN_Fundamentals.ipynb">
#         <img src="https://i.ibb.co/2P3SLwK/colab.png"  style="padding-bottom:5px;" />Run in Google Colab</a></td>
#   <td align="center"><a target="_blank" href="https://github.com/ezponda/intro_deep_learning/blob/main/class/Fundamentals/NN_Fundamentals.ipynb">
#         <img src="https://i.ibb.co/xfJbPmL/github.png"  height="70px" style="padding-bottom:5px;"  />View Source on GitHub</a></td>
# </table>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import numpy as np
import sklearn
import sklearn.datasets
import sklearn.linear_model
import matplotlib.pyplot as plt
# %matplotlib inline

tf.random.set_seed(0)

# %%
def plot_decision_boundary(model, X, y):
    # Set min and max values and give it some padding
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:,1].min() - 1, X[:,1].max() + 1
    h = 0.01
    # Generate a grid of points with distance h between them
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    # Predict the function value for the whole grid
    Z = model(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    # Plot the contour and training examples
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral)
    plt.ylabel('x2')
    plt.xlabel('x1')
    plt.scatter(X[:,0], X[:,1], c=y.ravel(), cmap=plt.cm.Spectral)
    
def load_planar_dataset(m, sigma=0.2):
    N = int(m/2) # number of points per class
    D = 2 # dimensionality
    X = np.zeros((m,D)) # data matrix where each row is a single example
    Y = np.zeros((m,1), dtype='uint8') # labels vector (0 for red, 1 for blue)
    a = 4 # maximum ray of the flower

    for j in range(2):
        ix = range(N*j,N*(j+1))
        t = np.linspace(j*3.12,(j+1)*3.12,N) + np.random.randn(N)*sigma # theta
        r = a*np.sin(4*t) + np.random.randn(N)*sigma # radius
        X[ix] = np.c_[r*np.sin(t), r*np.cos(t)]
        Y[ix] = j
        
    ## premuting ouput
    p = np.random.permutation(m)
    X = X[p,:]
    Y = Y[p,:]

    return X, Y.ravel()

def draw_neural_net(left, right, bottom, top, layer_sizes):
    '''
    From https://gist.github.com/craffel/2d727968c3aaebd10359#file-draw_neural_net-py
    Draw a neural network cartoon using matplotilb.
    
    :usage:
        >>> fig = plt.figure(figsize=(12, 12))
        >>> draw_neural_net(fig.gca(), .1, .9, .1, .9, [4, 7, 2])
    
    :parameters:
        - ax : matplotlib.axes.AxesSubplot
            The axes on which to plot the cartoon (get e.g. by plt.gca())
        - left : float
            The center of the leftmost node(s) will be placed here
        - right : float
            The center of the rightmost node(s) will be placed here
        - bottom : float
            The center of the bottommost node(s) will be placed here
        - top : float
            The center of the topmost node(s) will be placed here
        - layer_sizes : list of int
            List of layer sizes, including input and output dimensionality
    '''
    fig = plt.figure(figsize=(3, 3))
    ax = fig.gca()
    ax.axis('off')

    n_layers = len(layer_sizes)
    v_spacing = (top - bottom)/float(max(layer_sizes))
    h_spacing = (right - left)/float(len(layer_sizes) - 1)
    # Nodes
    for n, layer_size in enumerate(layer_sizes):
        layer_top = v_spacing*(layer_size - 1)/2. + (top + bottom)/2.
        for m in range(layer_size):
            circle = plt.Circle((n*h_spacing + left, layer_top - m*v_spacing), v_spacing/4.,
                                color='w', ec='k', zorder=4)
            ax.add_artist(circle)
    # Edges
    for n, (layer_size_a, layer_size_b) in enumerate(zip(layer_sizes[:-1], layer_sizes[1:])):
        layer_top_a = v_spacing*(layer_size_a - 1)/2. + (top + bottom)/2.
        layer_top_b = v_spacing*(layer_size_b - 1)/2. + (top + bottom)/2.
        for m in range(layer_size_a):
            for o in range(layer_size_b):
                line = plt.Line2D([n*h_spacing + left, (n + 1)*h_spacing + left],
                                  [layer_top_a - m*v_spacing, layer_top_b - o*v_spacing], c='k')
                ax.add_artist(line)

# %% [markdown]
# ## Dataset
#
# We have a binary classification dataset. The target `y` has two possible values, {0,1} and the input vector `x` has two dimensions.

# %%
N = 5000
X, y = load_planar_dataset(N, 0.2)

# %% [markdown]
# Visualize the dataset using matplotlib. The data looks like a "flower" with some red (label y=0) and some blue (y=1) points. Your goal is to build a model to fit this data.

# %%
# Visualize the data:
plt.scatter(X[:,0], X[:,1], c=y.ravel(), s=40, cmap=plt.cm.Spectral);

# %%
# train test split
from sklearn.model_selection import train_test_split

(X_train, X_test, y_train, y_test) = train_test_split(
    X,
    y,
    test_size=0.2,
)

# %%
print('X shape:{0}, y shape:{1}'.format(X.shape, y.shape))
print('X_train shape:{0}, y_train shape:{1}'.format(X_train.shape,
                                                    y_train.shape))
print('X_test shape:{0}, y_test shape:{1}'.format(X_test.shape, y_test.shape))
# Out:
# X shape:(5000, 2), y shape:(5000,)
# X_train shape:(4000, 2), y_train shape:(4000,)
# X_test shape:(1000, 2), y_test shape:(1000,)

# %%
## X first example
X[0,:]
# Out:
# array([-1.43404849, -3.89172503])

# %%
## Y firsts examples
y[:8]
# Out:
# array([1, 1, 1, 1, 0, 0, 0, 0], dtype=uint8)

# %% [markdown]
# ## First NN in Keras
#
# ### Logistic regression
#
# Fully connected layers are defined using the [Dense](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense) class. We can specify the number of neurons as the first argument, and specify the activation function using the activation argument.
#
# ```python
# tf.keras.layers.Dense(
#     units, activation=None
# )
#
# ```
#
# - **units**: Number of neurons in the layer.
# - **activation**: Activation function to use, default function is `linear`, you can also use `sigmoid` for sigmoid activation or [other alternatives](https://www.tensorflow.org/api_docs/python/tf/keras/activations)
#
# For defining the input layer you can use `keras.Input(shape=(input_dimension,))` or define your input dimension in the first hidden layer.
#
# ```python
# layers.Dense(4, activation="sigmoid", input_shape=(input_dimension,))
#
# ```
#
# Build a network without hidden layer

# %%
draw_neural_net(.1, .9, .1, .9, [2, 1])

# %%
model = keras.Sequential()
# The dimension of the input is 2 (planar data)
# we have only one output layer with 1 neuron
model.add(keras.layers.Dense(1, input_shape=(2, ), activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 3
#
# =================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, show_shapes=True)

# %% [markdown]
# #### Compile
# Now we need to specify the loss function, the metrics and the optimizer. It is done using compile function in Keras.

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# #### Training model
# This is similar to a sklearn model.

# %%
model.fit(X_train, y_train, epochs=10,
          validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/10
# 100/100 [==============================] - 1s 4ms/step - loss: 0.8371 - accuracy: 0.6466 - val_loss: 0.8050 - val_accuracy: 0.6562
# Epoch 2/10
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7913 - accuracy: 0.6419 - val_loss: 0.7638 - val_accuracy: 0.6463
# Epoch 3/10
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7524 - accuracy: 0.6338 - val_loss: 0.7309 - val_accuracy: 0.6413
# Epoch 4/10
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7213 - accuracy: 0.6256 - val_loss: 0.7047 - val_accuracy: 0.6363
# Epoch 5/10
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6981 - accuracy: 0.6150 - val_loss: 0.6867 - val_accuracy: 0.6187
# Epoch 6/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6820 - accuracy: 0.6037 - val_loss: 0.6749 - val_accuracy: 0.6075
# Epoch 7/10
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6717 - accuracy: 0.5844 - val_loss: 0.6676 - val_accuracy: 0.5850
# Epoch 8/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6655 - accuracy: 0.5703 - val_loss: 0.6632 - val_accuracy: 0.5663
# Epoch 9/10
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6620 - accuracy: 0.5503 - val_loss: 0.6611 - val_accuracy: 0.5462
# Epoch 10/10
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6601 - accuracy: 0.5328 - val_loss: 0.6601 - val_accuracy: 0.5400

# %% [markdown]
# #### Making predictions

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Test Loss: 0.6592646837234497
# Test Accuracy: 0.5220000147819519

# %%
y_pred = model.predict(X_test)
y_pred[:3], y_test[:3]
# Out:
# (array([[0.62297606],
#         [0.76749754],
#         [0.5614871 ]], dtype=float32), array([1, 1, 1], dtype=uint8))

# %%
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
plt.title("Basic NN");

# %% [markdown]
# ### One hidden layer NN
#
# - One **input with 2 features (input_shape)**
# - **One hidden dense layer**,  with **3 neurons** and implemented with  **sigmoid activating function**
# - **One Output** (sigmoid output activation function)
#
# We can create layers incrementally with the method `add()`:

# %%
draw_neural_net(.1, .9, .1, .9, [2, 3, 1])

# %%
model = keras.Sequential()

## hidden layer with 3 neurons and sigmoid activation
## The first layer need to have the input_shape
model.add(layers.Dense(3, input_shape=(2,), activation='sigmoid'))

# output layer
model.add(layers.Dense(1, activation='sigmoid'))

## model summary
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 3)                 9
#
#  dense_2 (Dense)             (None, 1)                 4
#
# =================================================================
# Total params: 13
# Trainable params: 13
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# You can also define the model with a list of layers
# ```python
# model = keras.Sequential([
#     keras.Input(shape=(2, )),
#     layers.Dense(3, activation='sigmoid', name='layer1'),
#     layers.Dense(1, activation='sigmoid', name='layer3')
# ])
# ````

# %%
plot_model(model, show_shapes=True)

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=25, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/25
# 100/100 [==============================] - 1s 3ms/step - loss: 0.6894 - accuracy: 0.6122 - val_loss: 0.6856 - val_accuracy: 0.6225
# Epoch 2/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6853 - accuracy: 0.6347 - val_loss: 0.6821 - val_accuracy: 0.6438
# Epoch 3/25
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6817 - accuracy: 0.6500 - val_loss: 0.6788 - val_accuracy: 0.6500
# Epoch 4/25
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6780 - accuracy: 0.6394 - val_loss: 0.6755 - val_accuracy: 0.6325
# Epoch 5/25
# 100/100 [==============================] - 1s 5ms/step - loss: 0.6741 - accuracy: 0.6109 - val_loss: 0.6717 - val_accuracy: 0.6212
# Epoch 6/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6699 - accuracy: 0.6012 - val_loss: 0.6677 - val_accuracy: 0.6075
# Epoch 7/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6656 - accuracy: 0.5891 - val_loss: 0.6636 - val_accuracy: 0.5900
# Epoch 8/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6614 - accuracy: 0.5894 - val_loss: 0.6594 - val_accuracy: 0.6012
# Epoch 9/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6570 - accuracy: 0.5903 - val_loss: 0.6550 - val_accuracy: 0.6137
# Epoch 10/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6526 - accuracy: 0.5922 - val_loss: 0.6506 - val_accuracy: 0.6150
# Epoch 11/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6481 - accuracy: 0.5972 - val_loss: 0.6460 - val_accuracy: 0.6162
# Epoch 12/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6436 - accuracy: 0.6022 - val_loss: 0.6414 - val_accuracy: 0.6237
# Epoch 13/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6391 - accuracy: 0.6047 - val_loss: 0.6368 - val_accuracy: 0.6225
# Epoch 14/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6346 - accuracy: 0.6087 - val_loss: 0.6324 - val_accuracy: 0.6313
# Epoch 15/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6304 - accuracy: 0.6128 - val_loss: 0.6280 - val_accuracy: 0.6325
# Epoch 16/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6261 - accuracy: 0.6156 - val_loss: 0.6239 - val_accuracy: 0.6350
# Epoch 17/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6221 - accuracy: 0.6134 - val_loss: 0.6199 - val_accuracy: 0.6363
# Epoch 18/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6182 - accuracy: 0.6175 - val_loss: 0.6162 - val_accuracy: 0.6363
# Epoch 19/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6146 - accuracy: 0.6184 - val_loss: 0.6125 - val_accuracy: 0.6363
# Epoch 20/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6111 - accuracy: 0.6184 - val_loss: 0.6090 - val_accuracy: 0.6300
# Epoch 21/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6079 - accuracy: 0.6159 - val_loss: 0.6058 - val_accuracy: 0.6300
# Epoch 22/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6049 - accuracy: 0.6184 - val_loss: 0.6028 - val_accuracy: 0.6288
# Epoch 23/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6020 - accuracy: 0.6200 - val_loss: 0.5999 - val_accuracy: 0.6275
# Epoch 24/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5993 - accuracy: 0.6203 - val_loss: 0.5974 - val_accuracy: 0.6275
# Epoch 25/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.5969 - accuracy: 0.6191 - val_loss: 0.5948 - val_accuracy: 0.6250

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Test Loss: 0.5882565379142761
# Test Accuracy: 0.621999979019165

# %%
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
plt.title("1 Hidden layer NN");
#por lo menos ha aprendido una ligera curva

# %% [markdown]
# ### Question 1:
# ####  What happens if we change the activation function of the first hidden  layer to `'linear'`?

# %%
model = keras.Sequential()
## The first layer need to have the input_shape
## change the activation function
model.add(layers.Dense(3, input_shape=(2,), activation='linear'))
# output layer
model.add(layers.Dense(1, activation='sigmoid'))

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=25, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/25
# 100/100 [==============================] - 1s 4ms/step - loss: 1.3445 - accuracy: 0.4931 - val_loss: 1.2182 - val_accuracy: 0.4837
# Epoch 2/25
# 100/100 [==============================] - 0s 2ms/step - loss: 1.0766 - accuracy: 0.4941 - val_loss: 0.9804 - val_accuracy: 0.5088
# Epoch 3/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.8787 - accuracy: 0.5325 - val_loss: 0.8161 - val_accuracy: 0.5675
# Epoch 4/25
# 100/100 [==============================] - 1s 5ms/step - loss: 0.7557 - accuracy: 0.6150 - val_loss: 0.7234 - val_accuracy: 0.6725
# Epoch 5/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6938 - accuracy: 0.6497 - val_loss: 0.6817 - val_accuracy: 0.6250
# Epoch 6/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6693 - accuracy: 0.5691 - val_loss: 0.6664 - val_accuracy: 0.5437
# Epoch 7/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6613 - accuracy: 0.4950 - val_loss: 0.6618 - val_accuracy: 0.4750
# Epoch 8/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6591 - accuracy: 0.4622 - val_loss: 0.6601 - val_accuracy: 0.4600
# Epoch 9/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6586 - accuracy: 0.4638 - val_loss: 0.6597 - val_accuracy: 0.4712
# Epoch 10/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6585 - accuracy: 0.4672 - val_loss: 0.6597 - val_accuracy: 0.4800
# Epoch 11/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6585 - accuracy: 0.4753 - val_loss: 0.6596 - val_accuracy: 0.4837
# Epoch 12/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6587 - accuracy: 0.4775 - val_loss: 0.6596 - val_accuracy: 0.4938
# Epoch 13/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6585 - accuracy: 0.4744 - val_loss: 0.6595 - val_accuracy: 0.4938
# Epoch 14/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6585 - accuracy: 0.4784 - val_loss: 0.6596 - val_accuracy: 0.4975
# Epoch 15/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6587 - accuracy: 0.4822 - val_loss: 0.6597 - val_accuracy: 0.4787
# Epoch 16/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6586 - accuracy: 0.4812 - val_loss: 0.6597 - val_accuracy: 0.4837
# Epoch 17/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6587 - accuracy: 0.4622 - val_loss: 0.6596 - val_accuracy: 0.4888
# Epoch 18/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6586 - accuracy: 0.4837 - val_loss: 0.6596 - val_accuracy: 0.4850
# Epoch 19/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6586 - accuracy: 0.4803 - val_loss: 0.6595 - val_accuracy: 0.5013
# Epoch 20/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6586 - accuracy: 0.4725 - val_loss: 0.6595 - val_accuracy: 0.4975
# Epoch 21/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6586 - accuracy: 0.4756 - val_loss: 0.6595 - val_accuracy: 0.5025
# Epoch 22/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6585 - accuracy: 0.4803 - val_loss: 0.6595 - val_accuracy: 0.4963
# Epoch 23/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6586 - accuracy: 0.4859 - val_loss: 0.6595 - val_accuracy: 0.5013
# Epoch 24/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6586 - accuracy: 0.4725 - val_loss: 0.6596 - val_accuracy: 0.4888
# Epoch 25/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6588 - accuracy: 0.4681 - val_loss: 0.6596 - val_accuracy: 0.4875

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
plt.title("1 Hidden layer NN, linear activation");
# Out:
# Test Loss: 0.6562821269035339
# Test Accuracy: 0.46799999475479126

# %% [markdown]
# ### Question 2:
# ####  What happens if we add more neurons to the first hidden layer ?

# %%
draw_neural_net(.1, .9, .1, .9, [2, 5, 1])

# %%
model = keras.Sequential()

## The first layer need to have the input_shape
## set the number of neurons
model.add(layers.Dense(5, input_shape=(2,), activation='sigmoid'))

# output layer
model.add(layers.Dense(1, activation='sigmoid'))

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=25, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/25
# 100/100 [==============================] - 1s 4ms/step - loss: 0.9410 - accuracy: 0.5044 - val_loss: 0.8956 - val_accuracy: 0.4938
# Epoch 2/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.8329 - accuracy: 0.5044 - val_loss: 0.8030 - val_accuracy: 0.4938
# Epoch 3/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7598 - accuracy: 0.5044 - val_loss: 0.7418 - val_accuracy: 0.4938
# Epoch 4/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7139 - accuracy: 0.5044 - val_loss: 0.7044 - val_accuracy: 0.4938
# Epoch 5/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6864 - accuracy: 0.5088 - val_loss: 0.6820 - val_accuracy: 0.5288
# Epoch 6/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6704 - accuracy: 0.5744 - val_loss: 0.6688 - val_accuracy: 0.6137
# Epoch 7/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6607 - accuracy: 0.6556 - val_loss: 0.6607 - val_accuracy: 0.6425
# Epoch 8/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6543 - accuracy: 0.6300 - val_loss: 0.6548 - val_accuracy: 0.6137
# Epoch 9/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6495 - accuracy: 0.5831 - val_loss: 0.6503 - val_accuracy: 0.5600
# Epoch 10/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6454 - accuracy: 0.5509 - val_loss: 0.6465 - val_accuracy: 0.5638
# Epoch 11/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6416 - accuracy: 0.5597 - val_loss: 0.6426 - val_accuracy: 0.5612
# Epoch 12/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6377 - accuracy: 0.5650 - val_loss: 0.6389 - val_accuracy: 0.5700
# Epoch 13/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6338 - accuracy: 0.5750 - val_loss: 0.6348 - val_accuracy: 0.5763
# Epoch 14/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6296 - accuracy: 0.5822 - val_loss: 0.6308 - val_accuracy: 0.5813
# Epoch 15/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6253 - accuracy: 0.5950 - val_loss: 0.6264 - val_accuracy: 0.5900
# Epoch 16/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6206 - accuracy: 0.5991 - val_loss: 0.6218 - val_accuracy: 0.5987
# Epoch 17/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6159 - accuracy: 0.6044 - val_loss: 0.6171 - val_accuracy: 0.6000
# Epoch 18/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6108 - accuracy: 0.6103 - val_loss: 0.6122 - val_accuracy: 0.6025
# Epoch 19/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6057 - accuracy: 0.6181 - val_loss: 0.6070 - val_accuracy: 0.6062
# Epoch 20/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6004 - accuracy: 0.6237 - val_loss: 0.6017 - val_accuracy: 0.6087
# Epoch 21/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.5950 - accuracy: 0.6237 - val_loss: 0.5963 - val_accuracy: 0.6100
# Epoch 22/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.5895 - accuracy: 0.6359 - val_loss: 0.5908 - val_accuracy: 0.6388
# Epoch 23/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.5840 - accuracy: 0.6644 - val_loss: 0.5852 - val_accuracy: 0.6700
# Epoch 24/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.5784 - accuracy: 0.6816 - val_loss: 0.5797 - val_accuracy: 0.6850
# Epoch 25/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.5729 - accuracy: 0.6947 - val_loss: 0.5741 - val_accuracy: 0.6938

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
plt.title("1 Hidden layer NN, linear activation");
# Out:
# Test Loss: 0.5606604218482971
# Test Accuracy: 0.7110000252723694

# %% [markdown]
# ### Question 3:
# ####  What happens if we add one more hidden layer ?

# %%
draw_neural_net(.1, .9, .1, .9, [2, 3, 3, 1])

# %%
model = keras.Sequential()
# First hidden layer (need to innclude input_shape)
## Set the number of neurons
model.add(layers.Dense(3, input_shape=(2,), activation='sigmoid'))

# second hidden layer
## Complete the code
model.add(layers.Dense(3, activation = 'sigmoid'))

# output layer
model.add(layers.Dense(1, activation='sigmoid'))

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=25, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/25
# 100/100 [==============================] - 1s 4ms/step - loss: 0.7054 - accuracy: 0.4956 - val_loss: 0.6880 - val_accuracy: 0.5063
# Epoch 2/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6852 - accuracy: 0.5159 - val_loss: 0.6790 - val_accuracy: 0.5575
# Epoch 3/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6783 - accuracy: 0.6194 - val_loss: 0.6753 - val_accuracy: 0.6488
# Epoch 4/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6744 - accuracy: 0.6534 - val_loss: 0.6720 - val_accuracy: 0.6712
# Epoch 5/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6707 - accuracy: 0.6575 - val_loss: 0.6682 - val_accuracy: 0.6675
# Epoch 6/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6666 - accuracy: 0.6478 - val_loss: 0.6638 - val_accuracy: 0.6562
# Epoch 7/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6622 - accuracy: 0.6381 - val_loss: 0.6592 - val_accuracy: 0.6500
# Epoch 8/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6575 - accuracy: 0.6372 - val_loss: 0.6540 - val_accuracy: 0.6450
# Epoch 9/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6524 - accuracy: 0.6353 - val_loss: 0.6486 - val_accuracy: 0.6450
# Epoch 10/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6472 - accuracy: 0.6375 - val_loss: 0.6435 - val_accuracy: 0.6500
# Epoch 11/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6419 - accuracy: 0.6341 - val_loss: 0.6377 - val_accuracy: 0.6450
# Epoch 12/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6365 - accuracy: 0.6356 - val_loss: 0.6324 - val_accuracy: 0.6488
# Epoch 13/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6314 - accuracy: 0.6338 - val_loss: 0.6269 - val_accuracy: 0.6450
# Epoch 14/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6264 - accuracy: 0.6369 - val_loss: 0.6219 - val_accuracy: 0.6500
# Epoch 15/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6217 - accuracy: 0.6372 - val_loss: 0.6170 - val_accuracy: 0.6475
# Epoch 16/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6171 - accuracy: 0.6359 - val_loss: 0.6126 - val_accuracy: 0.6500
# Epoch 17/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6130 - accuracy: 0.6350 - val_loss: 0.6083 - val_accuracy: 0.6513
# Epoch 18/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6090 - accuracy: 0.6378 - val_loss: 0.6045 - val_accuracy: 0.6513
# Epoch 19/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6052 - accuracy: 0.6378 - val_loss: 0.6006 - val_accuracy: 0.6513
# Epoch 20/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6018 - accuracy: 0.6359 - val_loss: 0.5971 - val_accuracy: 0.6488
# Epoch 21/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.5987 - accuracy: 0.6366 - val_loss: 0.5940 - val_accuracy: 0.6513
# Epoch 22/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5958 - accuracy: 0.6378 - val_loss: 0.5911 - val_accuracy: 0.6500
# Epoch 23/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.5931 - accuracy: 0.6359 - val_loss: 0.5884 - val_accuracy: 0.6513
# Epoch 24/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.5907 - accuracy: 0.6369 - val_loss: 0.5862 - val_accuracy: 0.6513
# Epoch 25/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.5885 - accuracy: 0.6388 - val_loss: 0.5839 - val_accuracy: 0.6513

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
plt.title("1 Hidden layer NN, linear activation");
# Out:
# Test Loss: 0.5785107016563416
# Test Accuracy: 0.6309999823570251

# %% [markdown]
# ####  Use  the [hyperbolic tangent](https://mathworld.wolfram.com/HyperbolicTangent.html) activation `'tanh'` with the first simple model and compare the results with the sigmoid activation

# %%
model = keras.Sequential()
## The first layer need to have the input_shape
## change the activation function
model.add(layers.Dense(3, input_shape=(2,), activation='relu'))
# output layer
model.add(layers.Dense(1, activation='sigmoid'))

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=25, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/25
# 100/100 [==============================] - 1s 4ms/step - loss: 0.7436 - accuracy: 0.4028 - val_loss: 0.7196 - val_accuracy: 0.4425
# Epoch 2/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.7033 - accuracy: 0.4728 - val_loss: 0.6907 - val_accuracy: 0.4737
# Epoch 3/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6823 - accuracy: 0.4903 - val_loss: 0.6734 - val_accuracy: 0.5075
# Epoch 4/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6697 - accuracy: 0.5128 - val_loss: 0.6661 - val_accuracy: 0.5312
# Epoch 5/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6641 - accuracy: 0.5728 - val_loss: 0.6626 - val_accuracy: 0.5913
# Epoch 6/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6609 - accuracy: 0.5784 - val_loss: 0.6604 - val_accuracy: 0.5550
# Epoch 7/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6589 - accuracy: 0.5706 - val_loss: 0.6588 - val_accuracy: 0.5625
# Epoch 8/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6573 - accuracy: 0.5741 - val_loss: 0.6575 - val_accuracy: 0.5650
# Epoch 9/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6561 - accuracy: 0.5741 - val_loss: 0.6563 - val_accuracy: 0.5663
# Epoch 10/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6551 - accuracy: 0.5747 - val_loss: 0.6562 - val_accuracy: 0.5600
# Epoch 11/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6543 - accuracy: 0.5766 - val_loss: 0.6551 - val_accuracy: 0.5625
# Epoch 12/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6535 - accuracy: 0.5763 - val_loss: 0.6545 - val_accuracy: 0.5663
# Epoch 13/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6527 - accuracy: 0.5744 - val_loss: 0.6536 - val_accuracy: 0.5675
# Epoch 14/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6519 - accuracy: 0.5759 - val_loss: 0.6530 - val_accuracy: 0.5663
# Epoch 15/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6514 - accuracy: 0.5744 - val_loss: 0.6528 - val_accuracy: 0.5650
# Epoch 16/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6508 - accuracy: 0.5769 - val_loss: 0.6523 - val_accuracy: 0.5650
# Epoch 17/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6500 - accuracy: 0.5728 - val_loss: 0.6516 - val_accuracy: 0.5650
# Epoch 18/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6496 - accuracy: 0.5791 - val_loss: 0.6515 - val_accuracy: 0.5625
# Epoch 19/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6489 - accuracy: 0.5738 - val_loss: 0.6504 - val_accuracy: 0.5688
# Epoch 20/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6484 - accuracy: 0.5731 - val_loss: 0.6496 - val_accuracy: 0.5725
# Epoch 21/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6479 - accuracy: 0.5772 - val_loss: 0.6491 - val_accuracy: 0.5700
# Epoch 22/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6472 - accuracy: 0.5759 - val_loss: 0.6488 - val_accuracy: 0.5688
# Epoch 23/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6468 - accuracy: 0.5775 - val_loss: 0.6483 - val_accuracy: 0.5713
# Epoch 24/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6461 - accuracy: 0.5753 - val_loss: 0.6480 - val_accuracy: 0.5650
# Epoch 25/25
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6456 - accuracy: 0.5756 - val_loss: 0.6475 - val_accuracy: 0.5650

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
plt.title("1 Hidden layer NN, linear activation");
# Out:
# Test Loss: 0.6384104490280151
# Test Accuracy: 0.5649999976158142

# %% [markdown]
# ## Practice I
#
# Repeat the process with a different dataset.

# %%
N = 5000
X, y = sklearn.datasets.make_moons(n_samples=N, noise=.18)

# %%
# Visualize the data:
plt.scatter(X[:,0], X[:,1], c=y.ravel(), s=40, cmap=plt.cm.Spectral);

# %%
# train test split
from sklearn.model_selection import train_test_split

(X_train, X_test, y_train, y_test) = train_test_split(
    X,
    y,
    test_size=0.25,
)
print('X shape:{0}, y shape:{1}'.format(X.shape, y.shape))
print('X_train shape:{0}, y_train shape:{1}'.format(X_train.shape,
                                                    y_train.shape))
print('X_test shape:{0}, y_test shape:{1}'.format(X_test.shape, y_test.shape))
# Out:
# X shape:(5000, 2), y shape:(5000,)
# X_train shape:(3750, 2), y_train shape:(3750,)
# X_test shape:(1250, 2), y_test shape:(1250,)

# %% [markdown]
# ### Define your model

# %%
draw_neural_net(.1, .9, .1, .9, [2, 8, 8, 1])

# %%
model = keras.Sequential()
## The first layer need to have the input_shape
model.add(layers.Dense(8, input_shape=(2,), activation='tanh'))

## Second Layer, don't use input_shape
model.add(layers.Dense(8, activation = 'tanh'))

# output layer
model.add(layers.Dense(1, activation='tanh'))

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=35, validation_split=0.2, batch_size=64)
# Out:
# Epoch 1/35
# 47/47 [==============================] - 1s 5ms/step - loss: 1.1209 - accuracy: 0.8290 - val_loss: 1.0537 - val_accuracy: 0.8000
# Epoch 2/35
# 47/47 [==============================] - 0s 2ms/step - loss: 0.7774 - accuracy: 0.8223 - val_loss: 0.7343 - val_accuracy: 0.7933
# Epoch 3/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.5240 - accuracy: 0.8180 - val_loss: 0.4714 - val_accuracy: 0.7987
# Epoch 4/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4437 - accuracy: 0.8200 - val_loss: 0.4120 - val_accuracy: 0.8067
# Epoch 5/35
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3841 - accuracy: 0.8287 - val_loss: 0.3689 - val_accuracy: 0.8120
# Epoch 6/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3829 - accuracy: 0.8390 - val_loss: 0.3861 - val_accuracy: 0.8227
# Epoch 7/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3757 - accuracy: 0.8470 - val_loss: 0.3761 - val_accuracy: 0.8267
# Epoch 8/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3639 - accuracy: 0.8560 - val_loss: 0.3520 - val_accuracy: 0.8307
# Epoch 9/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3610 - accuracy: 0.8587 - val_loss: 0.3464 - val_accuracy: 0.8360
# Epoch 10/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3614 - accuracy: 0.8627 - val_loss: 0.3411 - val_accuracy: 0.8387
# Epoch 11/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3567 - accuracy: 0.8657 - val_loss: 0.3392 - val_accuracy: 0.8400
# Epoch 12/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3574 - accuracy: 0.8697 - val_loss: 0.3360 - val_accuracy: 0.8427
# Epoch 13/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3551 - accuracy: 0.8697 - val_loss: 0.3342 - val_accuracy: 0.8400
# Epoch 14/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3537 - accuracy: 0.8700 - val_loss: 0.3458 - val_accuracy: 0.8440
# Epoch 15/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3522 - accuracy: 0.8693 - val_loss: 0.3436 - val_accuracy: 0.8440
# Epoch 16/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3511 - accuracy: 0.8683 - val_loss: 0.3276 - val_accuracy: 0.8480
# Epoch 17/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3536 - accuracy: 0.8667 - val_loss: 0.3314 - val_accuracy: 0.8453
# Epoch 18/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3448 - accuracy: 0.8680 - val_loss: 0.3400 - val_accuracy: 0.8480
# Epoch 19/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3496 - accuracy: 0.8683 - val_loss: 0.3390 - val_accuracy: 0.8507
# Epoch 20/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3506 - accuracy: 0.8680 - val_loss: 0.3223 - val_accuracy: 0.8493
# Epoch 21/35
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3674 - accuracy: 0.8700 - val_loss: 0.3700 - val_accuracy: 0.8493
# Epoch 22/35
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3542 - accuracy: 0.8713 - val_loss: 0.3212 - val_accuracy: 0.8493
# Epoch 23/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3532 - accuracy: 0.8680 - val_loss: 0.3182 - val_accuracy: 0.8467
# Epoch 24/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3331 - accuracy: 0.8600 - val_loss: 0.3196 - val_accuracy: 0.8507
# Epoch 25/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3463 - accuracy: 0.8717 - val_loss: 0.3338 - val_accuracy: 0.8560
# Epoch 26/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3448 - accuracy: 0.8717 - val_loss: 0.3332 - val_accuracy: 0.8560
# Epoch 27/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3440 - accuracy: 0.8717 - val_loss: 0.3323 - val_accuracy: 0.8560
# Epoch 28/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3433 - accuracy: 0.8713 - val_loss: 0.3320 - val_accuracy: 0.8520
# Epoch 29/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3603 - accuracy: 0.8737 - val_loss: 0.3513 - val_accuracy: 0.8547
# Epoch 30/35
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3596 - accuracy: 0.8733 - val_loss: 0.3290 - val_accuracy: 0.8587
# Epoch 31/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3405 - accuracy: 0.8733 - val_loss: 0.3272 - val_accuracy: 0.8587
# Epoch 32/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3346 - accuracy: 0.8727 - val_loss: 0.3182 - val_accuracy: 0.8547
# Epoch 33/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3261 - accuracy: 0.8733 - val_loss: 0.3254 - val_accuracy: 0.8560
# Epoch 34/35
# 47/47 [==============================] - 0s 5ms/step - loss: 0.3278 - accuracy: 0.8720 - val_loss: 0.3094 - val_accuracy: 0.8573
# Epoch 35/35
# 47/47 [==============================] - 0s 6ms/step - loss: 0.3292 - accuracy: 0.8750 - val_loss: 0.3091 - val_accuracy: 0.8600

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
# Out:
# Test Loss: 0.35643091797828674
# Test Accuracy: 0.8679999709129333

# %% [markdown]
# ## Functional API
#
# The Keras Functional API allows defining the topology of the models as a [acyclic directed graph](https://en.wikipedia.org/wiki/Directed_acyclic_graph) of layers. Next we will build the same model as in the previous section but using the Keras Functional API.
#
# You need to start with an input data entry:
# ```python
#     inputs = keras.Input(shape=(8,))
# ```
#
# We define the layers that we will include in the network and the relationships between them. It is important to note that each line details the type of layer and its properties (number of neurons, activation function, name ...) and just at the end, in parentheses, the name of the variable in which we have saved the layer from which its output will connect to the input of the layer we are declaring.
# ```python
# layer_1 = layers.Dense(4, activation='sigmoid',
#                        name='layer_1')(inputs)
# layer_2 = layers.Dense(4, activation='sigmoid',
#                        name='layer_2')(layer_1)
# ```
#
# The "layer call" `Dense()(inputs)` action is like drawing an arrow from "inputs" to this layer you created. You're "passing" the inputs to the dense layer, and you get `layer_1` as the output.
#
#
#
# Finally, we define the network outputs:
# ```python
# outputs = layers.Dense(1, name='output_layer')(layer_2)
# ```
#
# We create the model specifying the inputs and outputs:
# ```python
# model = keras.Model(inputs=inputs, outputs=outputs)
# ```

# %%
draw_neural_net(.1, .9, .1, .9, [8, 4, 4, 1])

# %%
inputs = keras.Input(shape=(8, ), name='input_layer')
l_1 = layers.Dense(4, activation='relu', name='layer_1')(inputs)
l_2 = layers.Dense(4, activation='relu', name='layer_2')(l_1)
outputs = layers.Dense(1, name='output_layer')(l_2)

model = keras.Model(inputs=inputs, outputs=outputs, name='example_model')

model.summary()
# Out:
# Model: "example_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 8)]               0
#
#  layer_1 (Dense)             (None, 4)                 36
#
#  layer_2 (Dense)             (None, 4)                 20
#
#  output_layer (Dense)        (None, 1)                 5
#
# =================================================================
# Total params: 61
# Trainable params: 61
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, show_shapes=True)

# %% [markdown]
# ## Practice II
#
# Repeat the process with a different dataset and the **Functional API**

# %%
N = 5000
X, y = sklearn.datasets.make_circles(n_samples=N, factor=.65, noise=.065) # sklearn.datasets.make_moons(n_samples=N, noise=.15)

# %%
# Visualize the data:
plt.scatter(X[:,0], X[:,1], c=y.ravel(), s=40, cmap=plt.cm.Spectral);

# %%
# train test split
from sklearn.model_selection import train_test_split

(X_train, X_test, y_train, y_test) = train_test_split(
    X,
    y,
    test_size=0.25,
)
print('X shape:{0}, y shape:{1}'.format(X.shape, y.shape))
print('X_train shape:{0}, y_train shape:{1}'.format(X_train.shape,
                                                    y_train.shape))
print('X_test shape:{0}, y_test shape:{1}'.format(X_test.shape, y_test.shape))
# Out:
# X shape:(5000, 2), y shape:(5000,)
# X_train shape:(3750, 2), y_train shape:(3750,)
# X_test shape:(1250, 2), y_test shape:(1250,)

# %% [markdown]
# ### Define your model

# %%
inputs = keras.Input(shape=(2, ), name='input_layer')
## First hidden layer
l_1 = layers.Dense(8, activation='tanh')(inputs)
l_2 = layers.Dense(8, activation='tanh')(l_1)

## output layer
outputs = layers.Dense(1, activation = 'sigmoid', name='output_layer')(l_2)

model = keras.Model(inputs=inputs, outputs=outputs, name='example_model')

model.summary()
# Out:
# Model: "example_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 2)]               0
#
#  dense_55 (Dense)            (None, 8)                 24
#
#  dense_56 (Dense)            (None, 8)                 72
#
#  output_layer (Dense)        (None, 1)                 9
#
# =================================================================
# Total params: 105
# Trainable params: 105
# Non-trainable params: 0
# _________________________________________________________________

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=35, validation_split=0.2, batch_size=64)
# Out:
# Epoch 1/35
# 47/47 [==============================] - 1s 6ms/step - loss: 0.6976 - accuracy: 0.5007 - val_loss: 0.6956 - val_accuracy: 0.4933
# Epoch 2/35
# 47/47 [==============================] - 0s 2ms/step - loss: 0.6926 - accuracy: 0.5393 - val_loss: 0.6926 - val_accuracy: 0.5747
# Epoch 3/35
# 47/47 [==============================] - 0s 2ms/step - loss: 0.6913 - accuracy: 0.5683 - val_loss: 0.6912 - val_accuracy: 0.4867
# Epoch 4/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.6903 - accuracy: 0.5720 - val_loss: 0.6905 - val_accuracy: 0.5013
# Epoch 5/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.6886 - accuracy: 0.5413 - val_loss: 0.6890 - val_accuracy: 0.5520
# Epoch 6/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.6873 - accuracy: 0.5650 - val_loss: 0.6873 - val_accuracy: 0.5413
# Epoch 7/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.6848 - accuracy: 0.6453 - val_loss: 0.6853 - val_accuracy: 0.6400
# Epoch 8/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.6821 - accuracy: 0.6643 - val_loss: 0.6827 - val_accuracy: 0.6747
# Epoch 9/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.6792 - accuracy: 0.6347 - val_loss: 0.6794 - val_accuracy: 0.6933
# Epoch 10/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.6748 - accuracy: 0.6823 - val_loss: 0.6761 - val_accuracy: 0.6893
# Epoch 11/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.6702 - accuracy: 0.7113 - val_loss: 0.6713 - val_accuracy: 0.7253
# Epoch 12/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.6652 - accuracy: 0.7217 - val_loss: 0.6669 - val_accuracy: 0.7240
# Epoch 13/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.6597 - accuracy: 0.7160 - val_loss: 0.6613 - val_accuracy: 0.7213
# Epoch 14/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.6537 - accuracy: 0.7183 - val_loss: 0.6563 - val_accuracy: 0.7107
# Epoch 15/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.6474 - accuracy: 0.7033 - val_loss: 0.6503 - val_accuracy: 0.7107
# Epoch 16/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.6409 - accuracy: 0.7037 - val_loss: 0.6440 - val_accuracy: 0.7027
# Epoch 17/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.6338 - accuracy: 0.6973 - val_loss: 0.6381 - val_accuracy: 0.7080
# Epoch 18/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.6269 - accuracy: 0.7033 - val_loss: 0.6311 - val_accuracy: 0.7040
# Epoch 19/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.6197 - accuracy: 0.7080 - val_loss: 0.6234 - val_accuracy: 0.6880
# Epoch 20/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.6117 - accuracy: 0.7000 - val_loss: 0.6163 - val_accuracy: 0.7160
# Epoch 21/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.6035 - accuracy: 0.7140 - val_loss: 0.6071 - val_accuracy: 0.7147
# Epoch 22/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.5945 - accuracy: 0.7290 - val_loss: 0.5964 - val_accuracy: 0.7147
# Epoch 23/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.5838 - accuracy: 0.7357 - val_loss: 0.5855 - val_accuracy: 0.7453
# Epoch 24/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.5718 - accuracy: 0.7580 - val_loss: 0.5714 - val_accuracy: 0.7613
# Epoch 25/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.5580 - accuracy: 0.7867 - val_loss: 0.5561 - val_accuracy: 0.7840
# Epoch 26/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.5421 - accuracy: 0.8153 - val_loss: 0.5395 - val_accuracy: 0.8280
# Epoch 27/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.5248 - accuracy: 0.8490 - val_loss: 0.5216 - val_accuracy: 0.8547
# Epoch 28/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.5069 - accuracy: 0.8833 - val_loss: 0.5025 - val_accuracy: 0.8960
# Epoch 29/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4888 - accuracy: 0.9160 - val_loss: 0.4840 - val_accuracy: 0.9307
# Epoch 30/35
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4707 - accuracy: 0.9403 - val_loss: 0.4660 - val_accuracy: 0.9507
# Epoch 31/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4527 - accuracy: 0.9553 - val_loss: 0.4482 - val_accuracy: 0.9667
# Epoch 32/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4352 - accuracy: 0.9727 - val_loss: 0.4349 - val_accuracy: 0.9440
# Epoch 33/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4185 - accuracy: 0.9743 - val_loss: 0.4146 - val_accuracy: 0.9693
# Epoch 34/35
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4010 - accuracy: 0.9793 - val_loss: 0.3973 - val_accuracy: 0.9800
# Epoch 35/35
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3846 - accuracy: 0.9830 - val_loss: 0.3822 - val_accuracy: 0.9747

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
# Out:
# Test Loss: 0.3763611912727356
# Test Accuracy: 0.9768000245094299
